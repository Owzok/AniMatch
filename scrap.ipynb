# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup
import time

# %%
lst_years = [x for x in range(2000, 2024)]

lst_seasons = ["winter", "spring", "summer", "fall"]

# %%
lst_animes=[]

for year in lst_years:
    for season in lst_seasons:
        print("Vamos en ", season, year)
        response =requests.get("https://myanimelist.net/anime/season/"+str(year)+"/"+str(season))
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            
            div_elements = soup.find_all('div', class_='seasonal-anime-list')
            for div_anime_list in div_elements:
                for anime_window in div_anime_list.find_all("div", class_="js-anime-category-producer"):
                        url = anime_window.find("a", class_="link-title").get("href")
                        lst_animes.append(url.split("/")[-2])
# Out:
# Vamos en  winter 2000
# Vamos en  spring 2000
# Vamos en  summer 2000
# Vamos en  fall 2000
# Vamos en  winter 2001
# Vamos en  spring 2001
# Vamos en  summer 2001
# Vamos en  fall 2001
# Vamos en  winter 2002
# Vamos en  spring 2002
# Vamos en  summer 2002
# Vamos en  fall 2002
# Vamos en  winter 2003
# Vamos en  spring 2003
# Vamos en  summer 2003
# Vamos en  fall 2003
# Vamos en  winter 2004
# Vamos en  spring 2004
# Vamos en  summer 2004
# Vamos en  fall 2004
# Vamos en  winter 2005
# Vamos en  spring 2005
# Vamos en  summer 2005
# Vamos en  fall 2005
# Vamos en  winter 2006
# Vamos en  spring 2006
# Vamos en  summer 2006
# Vamos en  fall 2006
# Vamos en  winter 2007
# Vamos en  spring 2007
# Vamos en  summer 2007
# Vamos en  fall 2007
# Vamos en  winter 2008
# Vamos en  spring 2008
# Vamos en  summer 2008
# Vamos en  fall 2008
# Vamos en  winter 2009
# Vamos en  spring 2009
# Vamos en  summer 2009
# Vamos en  fall 2009
# Vamos en  winter 2010
# Vamos en  spring 2010
# Vamos en  summer 2010
# Vamos en  fall 2010
# Vamos en  winter 2011
# Vamos en  spring 2011
# Vamos en  summer 2011
# Vamos en  fall 2011
# Vamos en  winter 2012
# Vamos en  spring 2012
# Vamos en  summer 2012
# Vamos en  fall 2012
# Vamos en  winter 2013
# Vamos en  spring 2013
# Vamos en  summer 2013
# Vamos en  fall 2013
# Vamos en  winter 2014
# Vamos en  spring 2014
# Vamos en  summer 2014
# Vamos en  fall 2014
# Vamos en  winter 2015
# Vamos en  spring 2015
# Vamos en  summer 2015
# Vamos en  fall 2015
# Vamos en  winter 2016
# Vamos en  spring 2016
# Vamos en  summer 2016
# Vamos en  fall 2016
# Vamos en  winter 2017
# Vamos en  spring 2017
# Vamos en  summer 2017
# Vamos en  fall 2017
# Vamos en  winter 2018
# Vamos en  spring 2018
# Vamos en  summer 2018
# Vamos en  fall 2018
# Vamos en  winter 2019
# Vamos en  spring 2019
# Vamos en  summer 2019
# Vamos en  fall 2019
# Vamos en  winter 2020
# Vamos en  spring 2020
# Vamos en  summer 2020
# Vamos en  fall 2020
# Vamos en  winter 2021
# Vamos en  spring 2021
# Vamos en  summer 2021
# Vamos en  fall 2021
# Vamos en  winter 2022
# Vamos en  spring 2022
# Vamos en  summer 2022
# Vamos en  fall 2022
# Vamos en  winter 2023
# Vamos en  spring 2023
# Vamos en  summer 2023
# Vamos en  fall 2023

# %%
with open("./animes_ids.txt", "r") as file:
    # Read the content of the file and split it into lines
    lines = file.read().split('\n')
df = pd.DataFrame({'Number': lines})
df
# Out:
#       Number
# 0        369
# 1        888
# 2        351
# 3        606
# 4       1137
# ...      ...
# 14430  55237
# 14431  56741
# 14432  56743
# 14433  55802
# 14434
#
# [14435 rows x 1 columns]

# %%
lst_animes = list(df["Number"].unique()[:-1])
lst_animes
with open("animes_ids.txt", 'w') as file:
    for number in lst_animes:
        file.write(str(number) + '\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Martin\AniMatch\scrap.ipynb Cell 5 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Martin/AniMatch/scrap.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> lst_animes = list(df["Number"].unique()[:-1])
#       <a href='vscode-notebook-cell:/c%3A/Users/Martin/AniMatch/scrap.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> lst_animes
#       <a href='vscode-notebook-cell:/c%3A/Users/Martin/AniMatch/scrap.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> with open("animes_ids.txt", 'w') as file:
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Correr desde aca hasta ...

# %%
with open("./animes_ids.txt", "r") as file:
    # Read the content of the file and split it into lines
    lines = file.read().split('\n')

# %%
df = pd.DataFrame({'Number': lines})
df
# Out:
#       Number
# 0        369
# 1        888
# 2        351
# 3        606
# 4       1137
# ...      ...
# 14430  55237
# 14431  56741
# 14432  56743
# 14433  55802
# 14434
#
# [14435 rows x 1 columns]

# %%
url = "https://myanimelist.net/anime/"

# %%
df_animes = []


#if the for fails, save the data frame file 
for x in range(len(df)):
    info_dict = {
            "ID": "Unknown",
            "Type": "Unknown",
            "Episodes": "Unknown",
            "Status": "Unknown",
            "Aired": "Unknown",
            "Premiered": "Unknown",
            "Producers": "Unknown",
            "Licensors": "Unknown",
            "Studios": "Unknown",
            "Source": "Unknown",
            "Genres": "Unknown",
            "Duration": "Unknown",
            "Rating": "Unknown",
            "Favorites": "Unknown",
            "Title_Eng": "Unknown",
            "Title": "Unknown",
            "Score": "Unknown",
            "Ranked": "Unknown",
            "Members": "Unknown",
            "Favorites": "Unknown",
            "Popularity": "Unknown",
            "Synopsis":"Unknown"
        }

    
    id = df.iloc[x]['Number']
    
    if x % 80 == 0 and x > 0:
        time.sleep(200)

    if x % 100 == 0:
        print(x)

    response = requests.get(url+str(id))

    soup = BeautifulSoup(response.text, 'html.parser')

    try:
        info_dict = {
            "ID": "Unknown",
            "Type": "Unknown",
            "Episodes": "Unknown",
            "Status": "Unknown",
            "Aired": "Unknown",
            "Premiered": "Unknown",
            "Producers": "Unknown",
            "Licensors": "Unknown",
            "Studios": "Unknown",
            "Source": "Unknown",
            "Genres": "Unknown",
            "Duration": "Unknown",
            "Rating": "Unknown",
            "Favorites": "Unknown",
            "Title_Eng": "Unknown",
            "Title": "Unknown",
            "Score": "Unknown",
            "Ranked": "Unknown",
            "Members": "Unknown",
            "Favorites": "Unknown",
            "Popularity": "Unknown",
            "Synopsis":"Unknown"
        }
        info_dict["ID"] = id
        
        # Find all div elements with class "spaceit_pad"
        spaceit_pad_divs = soup.find_all('div', class_='spaceit_pad')

        # Loop through the "spaceit_pad" divs to extract the information
        for div in spaceit_pad_divs:
            non_html_text = ''.join([str(item) if item.name is None else '' for item in div.contents]).strip()
            span = div.find('span')
            if span:
                span_text = span.get_text()
                a = div.find('a')
                if "Type:" in span_text and a:
                    info_dict["Type"] = a.get_text()
                elif "Episodes:" in span_text:
                    info_dict["Episodes"] = non_html_text
                elif "Status:" in span_text:
                    info_dict["Status"] = non_html_text
                elif "Aired:" in span_text:
                    info_dict["Aired"] = non_html_text
                elif "Premiered:" in span_text and a:
                    info_dict["Premiered"] = a.get_text()
                elif "Producers:" in span_text and a:
                    info_dict["Producers"] = a.get_text()
                elif "Licensors:" in span_text and a:
                    info_dict["Licensors"] = a.get_text()
                elif "Studios:" in span_text and a:
                    info_dict["Studios"] = a.get_text()
                elif "Source:" in span_text:
                    info_dict["Source"] = non_html_text
                elif "Genres:" in span_text:
                    genres = div.find_all('a')
                    if genres:
                        info_dict["Genres"] = ", ".join(a.get_text() for a in genres)
                elif "Duration:" in span_text:
                    info_dict["Duration"] = non_html_text
                elif "Rating:" in span_text:
                    info_dict["Rating"] = non_html_text
                elif "Favorites:" in span_text:
                    info_dict["Favorites"] = non_html_text.replace(',', '')

        # Find the <p> element with itemprop="description"
        description_p = soup.find('p', itemprop='description')
        if description_p:
            # Split the text by lines
            lines = description_p.text.split('\n')
            # Check if the last line starts with "(Source:" and remove it
            if lines and lines[-1].strip().startswith("(Source:"):
                lines.pop()
            # Reconstruct the text without the last line
            description_p = '\n'.join(lines).strip()
            # Extract the cleaned text inside the <p> element
            info_dict["Synopsis"] = description_p


        score = soup.find('div', class_='fl-l score')
        if score:
            score = score.find('div', class_='score-label')
            info_dict["Score"] = float(score.text.strip())

        rank = soup.find('span', class_='numbers ranked')
        if rank:
            info_dict["Ranked"] = rank.strong.text.strip('#')

        popularity = soup.find('span', class_='numbers popularity')
        if popularity:
            info_dict["Popularity"] = popularity.strong.text.strip('#')

        members = soup.find('span', class_='numbers members')
        if members:
            info_dict["Members"] = members.strong.text.replace(',', '')


        title_name = soup.find('h1', class_='title-name h1_bold_none')
        if title_name:
            info_dict["Title"] = title_name.text


        title_english = soup.find('p', class_='title-english title-inherit')
        if title_english:
            info_dict["Title_Eng"] = title_english.text

        df_animes.append(info_dict)

    except Exception as e:
        print(f"Error occurred for ID {id}: {str(e)}")

        df_animes_df = pd.DataFrame(df_animes)
        df_animes_df.to_csv("anime_data.csv", index=False)

df_animes_df = pd.DataFrame(df_animes)
df_animes_df.to_csv("anime_data.csv", index=False)
# Out:
# 0
# Error occurred for ID 8195: could not convert string to float: 'N/A'
# Error occurred for ID 32136: could not convert string to float: 'N/A'
# Error occurred for ID 29375: could not convert string to float: 'N/A'
# Error occurred for ID 2701: could not convert string to float: 'N/A'
# Error occurred for ID 29367: could not convert string to float: 'N/A'
# Error occurred for ID 23799: could not convert string to float: 'N/A'
# Error occurred for ID 30116: could not convert string to float: 'N/A'
# Error occurred for ID 29369: could not convert string to float: 'N/A'
# Error occurred for ID 29487: could not convert string to float: 'N/A'
# Error occurred for ID 48197: could not convert string to float: 'N/A'
# Error occurred for ID 55285: could not convert string to float: 'N/A'
# Error occurred for ID 21975: could not convert string to float: 'N/A'
# Error occurred for ID 42399: could not convert string to float: 'N/A'
# Error occurred for ID 27497: could not convert string to float: 'N/A'
# Error occurred for ID 52646: could not convert string to float: 'N/A'
# 100
# Error occurred for ID 11203: could not convert string to float: 'N/A'
# Error occurred for ID 25063: could not convert string to float: 'N/A'
# Error occurred for ID 28117: could not convert string to float: 'N/A'
# Error occurred for ID 52154: could not convert string to float: 'N/A'
# Error occurred for ID 7715: could not convert string to float: 'N/A'
# Error occurred for ID 42279: could not convert string to float: 'N/A'
# Error occurred for ID 53968: could not convert string to float: 'N/A'
# Error occurred for ID 41880: could not convert string to float: 'N/A'
# Error occurred for ID 48347: could not convert string to float: 'N/A'
# Error occurred for ID 45344: could not convert string to float: 'N/A'
# Error occurred for ID 19695: could not convert string to float: 'N/A'
# Error occurred for ID 17405: could not convert string to float: 'N/A'
# Error occurred for ID 52155: could not convert string to float: 'N/A'
# Error occurred for ID 21297: could not convert string to float: 'N/A'
# Error occurred for ID 16480: could not convert string to float: 'N/A'
# Error occurred for ID 53963: could not convert string to float: 'N/A'
# 200
# Error occurred for ID 48904: could not convert string to float: 'N/A'
# Error occurred for ID 52158: could not convert string to float: 'N/A'
# Error occurred for ID 42400: could not convert string to float: 'N/A'
# Error occurred for ID 41203: could not convert string to float: 'N/A'
# Error occurred for ID 25089: could not convert string to float: 'N/A'
# Error occurred for ID 52809: could not convert string to float: 'N/A'
# Error occurred for ID 52641: could not convert string to float: 'N/A'
# Error occurred for ID 34490: could not convert string to float: 'N/A'
# Error occurred for ID 48134: could not convert string to float: 'N/A'
# Error occurred for ID 48206: could not convert string to float: 'N/A'
# 300
# Error occurred for ID 50137: could not convert string to float: 'N/A'
# Error occurred for ID 16460: could not convert string to float: 'N/A'
# Error occurred for ID 25071: could not convert string to float: 'N/A'
# Error occurred for ID 17487: could not convert string to float: 'N/A'
# Error occurred for ID 32590: could not convert string to float: 'N/A'
# Error occurred for ID 29373: could not convert string to float: 'N/A'
# Error occurred for ID 35576: could not convert string to float: 'N/A'
# Error occurred for ID 52156: could not convert string to float: 'N/A'
# Error occurred for ID 53961: could not convert string to float: 'N/A'
# 400
# Error occurred for ID 25073: could not convert string to float: 'N/A'
# Error occurred for ID 25081: could not convert string to float: 'N/A'
# Error occurred for ID 25075: could not convert string to float: 'N/A'
# Error occurred for ID 44683: could not convert string to float: 'N/A'
# Error occurred for ID 4940: could not convert string to float: 'N/A'
# Error occurred for ID 11525: could not convert string to float: 'N/A'
# Error occurred for ID 32580: could not convert string to float: 'N/A'
# Error occurred for ID 35575: could not convert string to float: 'N/A'
# Error occurred for ID 53508: could not convert string to float: 'N/A'
# Error occurred for ID 48216: could not convert string to float: 'N/A'
# 500
# Error occurred for ID 34892: could not convert string to float: 'N/A'
# Error occurred for ID 25085: could not convert string to float: 'N/A'
# Error occurred for ID 52622: could not convert string to float: 'N/A'
# Error occurred for ID 53509: could not convert string to float: 'N/A'
# Error occurred for ID 10989: could not convert string to float: 'N/A'
# Error occurred for ID 53025: could not convert string to float: 'N/A'
# Error occurred for ID 50176: could not convert string to float: 'N/A'
# Error occurred for ID 22279: could not convert string to float: 'N/A'
# 600
# Error occurred for ID 52194: could not convert string to float: 'N/A'
# Error occurred for ID 7525: could not convert string to float: 'N/A'
# Error occurred for ID 48215: could not convert string to float: 'N/A'
# Error occurred for ID 38174: could not convert string to float: 'N/A'
# Error occurred for ID 41027: could not convert string to float: 'N/A'
# Error occurred for ID 19907: could not convert string to float: 'N/A'
# Error occurred for ID 53941: could not convert string to float: 'N/A'
# 700
# Error occurred for ID 31054: could not convert string to float: 'N/A'
# Error occurred for ID 18005: could not convert string to float: 'N/A'
# Error occurred for ID 24355: could not convert string to float: 'N/A'
# Error occurred for ID 35577: could not convert string to float: 'N/A'
# Error occurred for ID 9304: could not convert string to float: 'N/A'
# Error occurred for ID 53939: could not convert string to float: 'N/A'
# Error occurred for ID 10237: could not convert string to float: 'N/A'
# Error occurred for ID 37798: could not convert string to float: 'N/A'
# Error occurred for ID 53022: could not convert string to float: 'N/A'
# 800
# Error occurred for ID 12799: could not convert string to float: 'N/A'
# Error occurred for ID 31052: could not convert string to float: 'N/A'
# Error occurred for ID 35520: could not convert string to float: 'N/A'
# Error occurred for ID 35521: could not convert string to float: 'N/A'
# Error occurred for ID 23523: could not convert string to float: 'N/A'
# Error occurred for ID 50313: could not convert string to float: 'N/A'
# 900
# Error occurred for ID 25597: could not convert string to float: 'N/A'
# Error occurred for ID 42198: could not convert string to float: 'N/A'
# Error occurred for ID 7750: could not convert string to float: 'N/A'
# Error occurred for ID 55624: could not convert string to float: 'N/A'
# Error occurred for ID 28091: could not convert string to float: 'N/A'
# Error occurred for ID 34688: could not convert string to float: 'N/A'
# Error occurred for ID 50938: could not convert string to float: 'N/A'
# 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Martin\AniMatch\scrap.ipynb Cell 10 line <cell line: 5>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Martin/AniMatch/scrap.ipynb#X12sZmlsZQ%3D%3D?line=36'>37</a> if x % 100 == 0:
#      <a href='vscode-notebook-cell:/c%3A/Users/Martin/AniMatch/scrap.ipynb#X12sZmlsZQ%3D%3D?line=37'>38</a>     print(x)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Martin/AniMatch/scrap.ipynb#X12sZmlsZQ%3D%3D?line=39'>40</a> response = requests.get(url+str(id))
#      <a href='vscode-notebook-cell:/c%3A/Users/Martin/AniMatch/scrap.ipynb#X12sZmlsZQ%3D%3D?line=41'>42</a> soup = BeautifulSoup(response.text, 'html.parser')
#      <a href='vscode-notebook-cell:/c%3A/Users/Martin/AniMatch/scrap.ipynb#X12sZmlsZQ%3D%3D?line=43'>44</a> try:
#
# File c:\Python310\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Python310\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Python310\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Python310\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Python310\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File c:\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Python310\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Python310\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File c:\Python310\lib\site-packages\urllib3\connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File c:\Python310\lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File c:\Python310\lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File c:\Python310\lib\ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File c:\Python310\lib\ssl.py:1071, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1068         if timeout == 0.0:
#    1069             # non-blocking
#    1070             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071         self.do_handshake()
#    1072 except (OSError, ValueError):
#    1073     self.close()
#
# File c:\Python310\lib\ssl.py:1342, in SSLSocket.do_handshake(self, block)
#    1340     if timeout == 0.0 and block:
#    1341         self.settimeout(None)
# -> 1342     self._sslobj.do_handshake()
#    1343 finally:
#    1344     self.settimeout(timeout)
#
# KeyboardInterrupt:
